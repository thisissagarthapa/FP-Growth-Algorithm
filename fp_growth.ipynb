# %% [markdown]
# ## FP-Growth Algorithm

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("amazon_transactions.csv")

# %%
dataset.head(3)
# Out:
#   Transaction ID      Product Name Product Category  Price  Quantity  \
# 0       TXN00001  Non-fiction Book            Books     20         2
# 1       TXN00002      Fiction Book            Books     15         3
# 2       TXN00003   Electric Kettle  Home Appliances     30         1
#
#   Purchase Date Customer ID Payment Method Shipping Country
# 0    2023-12-30    CUST7294     Debit Card            Nepal
# 1    2024-10-16    CUST4500      Gift Card        Australia
# 2    2024-02-09    CUST1201         PayPal           Canada

# %%
dataset.drop(columns=["Transaction ID","Purchase Date"],inplace=True)

# %%
dataset.head(3)
# Out:
#        Product Name Product Category  Price  Quantity Customer ID  \
# 0  Non-fiction Book            Books     20         2    CUST7294
# 1      Fiction Book            Books     15         3    CUST4500
# 2   Electric Kettle  Home Appliances     30         1    CUST1201
#
#   Payment Method Shipping Country
# 0     Debit Card            Nepal
# 1      Gift Card        Australia
# 2         PayPal           Canada

# %%
market = []
for i in range(dataset.shape[0]):  # Loop through each row
    cus = []
    for j in dataset.columns:
            if type(dataset[j][i])==str:              
               cus.append(dataset[j][i])  # Access the value in column 'j' and row 'i'
    market.append(cus)  # Add the row data to 'market'

# %%
list=[]
for i in market:
    for j in i:
        list.append(j)

# %%
import collections

# %%
col=collections.Counter(list)

# %%
d={"item_name":col.keys(),"values":col.values()}

# %%
df1=pd.DataFrame(d).sort_values(by=["values"],ascending=False)

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr=TransactionEncoder()
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
df2=pd.DataFrame(tr.transform(market),columns=tr.columns_)

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
fp=fpgrowth(df2,use_colnames=True,max_len=3,min_support=0.05).sort_values(by=["support"],ascending=False)
fp
# Out:
#     support                                itemsets
# 11    0.217                           (Credit Card)
# 3     0.205                             (Gift Card)
# 9     0.197                            (Amazon Pay)
# 5     0.197                       (Home Appliances)
# 6     0.196                                (PayPal)
# 0     0.185                            (Debit Card)
# 18    0.144                           (Electronics)
# 12    0.143                               (Fashion)
# 19    0.140                                 (Japan)
# 28    0.131                               (Germany)
# 1     0.129                                 (Nepal)
# 10    0.128                                   (USA)
# 13    0.126                                    (UK)
# 16    0.116                             (Computers)
# 7     0.116                                (Canada)
# 8     0.115                                 (India)
# 4     0.115                             (Australia)
# ...
